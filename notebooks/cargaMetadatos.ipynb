# %% [markdown]
# # Creación de Metadatos por Capa Geográfica
#
# En el siguiente notebook se realiza la asignación de metadatos a los insumos obtenidos durante la limpieza de los mismos

# %%
# %pip install geopandas
# %pip install fiona
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Bibliotecas

from pathlib import Path
import geopandas as gpd
import fiona
import json
import sqlite3

# %%
ruta_gpkg = Path("/Users/gbv/datos/procesados/procesados_1_etapa")
print(carpeta)
# Out:
# /datos/procesados/procesados_1_etapa

# %%
capa1 = ruta_gpkg / "areas_verdes.gpkg"

metadato= {
  "areas_verdes.gpkg": {
    "titulo": "Areas Verdes en la Ciudad de México",
    "fuentes": [
      "Datos abiertos de la Ciudad de México: https://datos.cdmx.gob.mx/dataset/inventario-de-areas-verdes-en-la-ciudad-de-mexico"
    ],
    "fecha_descarga": "2026-04-10",
    "licencias": [
      "Español - Creative Commons Attribution 4.0"
    ],
    "descripcion": "Representa áreas verdes urbanas. Capa geográfica 'areas_verdes' en formato GeoPackage con geometría tipo MultiPolygon y 11675 entidades.",
    "archivo": "areas_verdes.gpkg",
    "formato": "GeoPackage",
    "capas": [
      {
        "nombre_capa": "areas_verdes",
        "tipo_geometria": "MultiPolygon",
        "numero_entidades": 11675,
        "crs": "GEOGCS[\"WGS 84\",DATUM[\"WGS_1984\",SPHEROID[\"WGS 84\",6378137,298.257223563,AUTHORITY[\"EPSG\",\"7030\"]],AUTHORITY[\"EPSG\",\"6326\"]],PRIMEM[\"Greenwich\",0,AUTHORITY[\"EPSG\",\"8901\"]],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]],AXIS[\"Latitude\",NORTH],AXIS[\"Longitude\",EAST],AUTHORITY[\"EPSG\",\"4326\"]]",
        "descripcion": "Representa áreas verdes urbanas. Capa geográfica 'areas_verdes' en formato GeoPackage con geometría tipo MultiPolygon y 11675 entidades.",
        "variables": {
          "categoria": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: categoria."
          },
          "subcat_sed": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: subcat_sed."
          },
          "superficie": {
            "tipo": "float",
            "descripcion": "Variable original del insumo: superficie."
          },
          "perimetro": {
            "tipo": "float",
            "descripcion": "Variable original del insumo: perimetro."
          },
          "muerdago": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: muerdago."
          }
        }
      }
    ]
  }}

ruta_json = capa1.with_suffix(".json")

# Guardamos el archivo
with open(ruta_json, "w", encoding="utf-8") as archivo:
    json.dump(metadato, archivo, ensure_ascii=False, indent=4)

# %%
capa2 = ruta_gpkg / "cablebus_estaciones.gpkg"

metadato= {"cablebus_estaciones.gpkg": {
    "titulo": "Estaciones del Cablebus ",
    "fuentes": [
      "Datos abiertos de la Ciudad de México: https://datos.cdmx.gob.mx/dataset/inventario-de-areas-verdes-en-la-ciudad-de-mexico"
    ],
    "fecha_descarga": "2026-04-10",
    "licencias": [
      "Español - Creative Commons Attribution 4.0"
    ],
    "descripcion": "Representa estaciones del sistema Cablebús. Capa geográfica 'cablebus_estaciones' en formato GeoPackage con geometría tipo 3D Point y 19 entidades.",
    "archivo": "cablebus_estaciones.gpkg",
    "formato": "GeoPackage",
    "capas": [
      {
        "nombre_capa": "cablebus_estaciones",
        "tipo_geometria": "3D Point",
        "numero_entidades": 19,
        "crs": "GEOGCS[\"WGS 84\",DATUM[\"WGS_1984\",SPHEROID[\"WGS 84\",6378137,298.257223563,AUTHORITY[\"EPSG\",\"7030\"]],AUTHORITY[\"EPSG\",\"6326\"]],PRIMEM[\"Greenwich\",0,AUTHORITY[\"EPSG\",\"8901\"]],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]],AXIS[\"Latitude\",NORTH],AXIS[\"Longitude\",EAST],AUTHORITY[\"EPSG\",\"4326\"]]",
        "descripcion": "Representa estaciones del sistema Cablebús. Capa geográfica 'cablebus_estaciones' en formato GeoPackage con geometría tipo 3D Point y 19 entidades.",
        "variables": {
          "SISTEMA": {
            "tipo": "str",
            "descripcion": "Sistema de transporte o programa al que pertenece el elemento."
          },
          "NOMBRE": {
            "tipo": "str",
            "descripcion": "Nombre del elemento geográfico o registro."
          },
          "LINEA": {
            "tipo": "str",
            "descripcion": "Identificador o nombre de la línea de transporte."
          },
          "TIPO": {
            "tipo": "str",
            "descripcion": "Tipo de elemento o clasificación general."
          },
          "ALCALDIAS": {
            "tipo": "str",
            "descripcion": "Alcaldía o conjunto de alcaldías asociadas al registro."
          }
        }
      }
    ]
  }}

ruta_json = capa2.with_suffix(".json")

# Guardamos el archivo
with open(ruta_json, "w", encoding="utf-8") as archivo:
    json.dump(metadato, archivo, ensure_ascii=False, indent=4)

# %%
capa3 = ruta_gpkg / "cablebus_lineas.gpkg"

metadato= {"cablebus_lineas.gpkg": {
    "titulo": "Cablebus Lineas",
    "fuentes": [
      "Datos abiertos de la Ciudad de México: https://datos.cdmx.gob.mx/dataset/inventario-de-areas-verdes-en-la-ciudad-de-mexico"
    ],
    "fecha_descarga": "2026-04-10",
    "licencias": [
      "Español - Creative Commons Attribution 4.0"
    ],
    "descripcion": "Representa líneas o rutas del sistema Cablebús. Capa geográfica 'cablebus_lineas' en formato GeoPackage con geometría tipo 3D LineString y 4 entidades.",
    "archivo": "cablebus_lineas.gpkg",
    "formato": "GeoPackage",
    "capas": [
      {
        "nombre_capa": "cablebus_lineas",
        "tipo_geometria": "3D LineString",
        "numero_entidades": 4,
        "crs": "GEOGCS[\"WGS 84\",DATUM[\"WGS_1984\",SPHEROID[\"WGS 84\",6378137,298.257223563,AUTHORITY[\"EPSG\",\"7030\"]],AUTHORITY[\"EPSG\",\"6326\"]],PRIMEM[\"Greenwich\",0,AUTHORITY[\"EPSG\",\"8901\"]],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]],AXIS[\"Latitude\",NORTH],AXIS[\"Longitude\",EAST],AUTHORITY[\"EPSG\",\"4326\"]]",
        "descripcion": "Representa líneas o rutas del sistema Cablebús. Capa geográfica 'cablebus_lineas' en formato GeoPackage con geometría tipo 3D LineString y 4 entidades.",
        "variables": {
          "SISTEMA": {
            "tipo": "str",
            "descripcion": "Sistema de transporte o programa al que pertenece el elemento."
          },
          "LINEA": {
            "tipo": "str",
            "descripcion": "Identificador o nombre de la línea de transporte."
          },
          "RUTA": {
            "tipo": "str",
            "descripcion": "Nombre o identificación de la ruta."
          }
        }
      }
    ]
  }}

ruta_json = capa3.with_suffix(".json")

# Guardamos el archivo
with open(ruta_json, "w", encoding="utf-8") as archivo:
    json.dump(metadato, archivo, ensure_ascii=False, indent=4)

# %%
capa4 = ruta_gpkg / "catastro_unificado_cdmx.gpkg"

metadato= {"catastro_unificado_cdmx.gpkg": {
    "titulo": "Catastro Unificado de la Ciudad de México",
    "fuentes": [
      "Datos abiertos de la Ciudad de México:  https://sig.cdmx.gob.mx/datos/descarga#d_datos_cat"
    ],
    "fecha_descarga": "2026-04-10",
    "licencias": [
      "Español - Creative Commons Attribution 4.0"
    ],
    "descripcion": "Representa información catastral unificada de la Ciudad de México. Capa geográfica 'catastro_unificado_cdmx' en formato GeoPackage con geometría tipo Polygon y 1089684 entidades.",
    "archivo": "catastro_unificado_cdmx.gpkg",
    "formato": "GeoPackage",
    "capas": [
      {
        "nombre_capa": "catastro_unificado_cdmx",
        "tipo_geometria": "Polygon",
        "numero_entidades": 1089684,
        "crs": "PROJCS[\"WGS 84 / UTM zone 14N\",GEOGCS[\"WGS 84\",DATUM[\"WGS_1984\",SPHEROID[\"WGS 84\",6378137,298.257223563,AUTHORITY[\"EPSG\",\"7030\"]],AUTHORITY[\"EPSG\",\"6326\"]],PRIMEM[\"Greenwich\",0,AUTHORITY[\"EPSG\",\"8901\"]],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]],AUTHORITY[\"EPSG\",\"4326\"]],PROJECTION[\"Transverse_Mercator\"],PARAMETER[\"latitude_of_origin\",0],PARAMETER[\"central_meridian\",-99],PARAMETER[\"scale_factor\",0.9996],PARAMETER[\"false_easting\",500000],PARAMETER[\"false_northing\",0],UNIT[\"metre\",1,AUTHORITY[\"EPSG\",\"9001\"]],AXIS[\"Easting\",EAST],AXIS[\"Northing\",NORTH],AUTHORITY[\"EPSG\",\"32614\"]]",
        "descripcion": "Representa información catastral unificada de la Ciudad de México. Capa geográfica 'catastro_unificado_cdmx' en formato GeoPackage con geometría tipo Polygon y 1089684 entidades.",
        "variables": {}
      }
    ]
  }}

ruta_json = capa4.with_suffix(".json")

# Guardamos el archivo
with open(ruta_json, "w", encoding="utf-8") as archivo:
    json.dump(metadato, archivo, ensure_ascii=False, indent=4)

# %%
capa5 = ruta_gpkg / "ciclovia_bid_limpia.gpkg"

metadato= {"ciclovia_bid_limpia.gpkg": {
    "titulo": "Infraestructura vial ciclista unificada",
    "fuentes": [
      "Datos abiertos de la Ciudad de México:  https://datos.cdmx.gob.mx/dataset/infraestructura-vial-ciclista"
    ],
    "fecha_descarga": "2026-04-10",
    "licencias": [
      "Español - Creative Commons Attribution 4.0"
    ],
    "descripcion": "Representa tramos de ciclovía BID. Capa geográfica 'ciclovia_bid_limpia' en formato GeoPackage con geometría tipo 3D MultiLineString y 61 entidades.",
    "archivo": "ciclovia_bid_limpia.gpkg",
    "formato": "GeoPackage",
    "capas": [
      {
        "nombre_capa": "ciclovia_bid_limpia",
        "tipo_geometria": "3D MultiLineString",
        "numero_entidades": 61,
        "crs": "GEOGCS[\"WGS 84\",DATUM[\"WGS_1984\",SPHEROID[\"WGS 84\",6378137,298.257223563,AUTHORITY[\"EPSG\",\"7030\"]],AUTHORITY[\"EPSG\",\"6326\"]],PRIMEM[\"Greenwich\",0,AUTHORITY[\"EPSG\",\"8901\"]],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]],AXIS[\"Latitude\",NORTH],AXIS[\"Longitude\",EAST],AUTHORITY[\"EPSG\",\"4326\"]]",
        "descripcion": "Representa tramos de ciclovía BID. Capa geográfica 'ciclovia_bid_limpia' en formato GeoPackage con geometría tipo 3D MultiLineString y 61 entidades.",
        "variables": {
          "ALCALDIA": {
            "tipo": "str",
            "descripcion": "Alcaldía asociada al registro."
          },
          "TIPO_IC": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: TIPO_IC."
          },
          "TIPO_VIA": {
            "tipo": "str",
            "descripcion": "Tipo de vialidad."
          },
          "TIPO_CONEC": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: TIPO_CONEC."
          },
          "LONG_KM": {
            "tipo": "float",
            "descripcion": "Longitud del tramo en kilómetros."
          }
        }
      }
    ]
  }}

ruta_json = capa5.with_suffix(".json")

# Guardamos el archivo
with open(ruta_json, "w", encoding="utf-8") as archivo:
    json.dump(metadato, archivo, ensure_ascii=False, indent=4)

# %%
capa6 = ruta_gpkg / "ciclovia_limpia.gpkg"

metadato= {"ciclovia_limpia.gpkg": {
    "titulo": "Infraestructura vial ciclista procesada",
    "fuentes": [
      "Datos abiertos de la Ciudad de México:  https://datos.cdmx.gob.mx/dataset/infraestructura-vial-ciclista"
    ],
    "fecha_descarga": "2026-04-10",
    "licencias": [
      "Español - Creative Commons Attribution 4.0"
    ],
    "descripcion": "Representa tramos de ciclovía. Capa geográfica 'ciclovia_limpia' en formato GeoPackage con geometría tipo 3D LineString y 221 entidades.",
    "archivo": "ciclovia_limpia.gpkg",
    "formato": "GeoPackage",
    "capas": [
      {
        "nombre_capa": "ciclovia_limpia",
        "tipo_geometria": "3D LineString",
        "numero_entidades": 221,
        "crs": "GEOGCS[\"WGS 84\",DATUM[\"WGS_1984\",SPHEROID[\"WGS 84\",6378137,298.257223563,AUTHORITY[\"EPSG\",\"7030\"]],AUTHORITY[\"EPSG\",\"6326\"]],PRIMEM[\"Greenwich\",0,AUTHORITY[\"EPSG\",\"8901\"]],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]],AXIS[\"Latitude\",NORTH],AXIS[\"Longitude\",EAST],AUTHORITY[\"EPSG\",\"4326\"]]",
        "descripcion": "Representa tramos de ciclovía. Capa geográfica 'ciclovia_limpia' en formato GeoPackage con geometría tipo 3D LineString y 221 entidades.",
        "variables": {
          "ALCALDIA": {
            "tipo": "str",
            "descripcion": "Alcaldía asociada al registro."
          },
          "TIPO_IC": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: TIPO_IC."
          },
          "TIPO_VIA": {
            "tipo": "str",
            "descripcion": "Tipo de vialidad."
          },
          "TIPO_CONEC": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: TIPO_CONEC."
          },
          "LONG_KM": {
            "tipo": "float",
            "descripcion": "Longitud del tramo en kilómetros."
          }
        }
      }
    ]
  }}

ruta_json = capa6.with_suffix(".json")

# Guardamos el archivo
with open(ruta_json, "w", encoding="utf-8") as archivo:
    json.dump(metadato, archivo, ensure_ascii=False, indent=4)

# %%
capa7 = ruta_gpkg / "colonias_cdmx.gpkg"

metadato= {"colonias_cdmx.gpkg": {
    "titulo": "Colonias de la Ciudad de México",
    "fuentes": [
      "Datos abiertos de la Ciudad de México: https://datos.cdmx.gob.mx/dataset/catalogo-de-colonias-datos-abiertos"
    ],
    "fecha_descarga": "2026-04-10",
    "licencias": [
      "Español - Creative Commons Attribution 4.0"
    ],
    "descripcion": "Representa colonias de la Ciudad de México. Capa geográfica 'catalogoColonias' en formato GeoPackage con geometría tipo Polygon y 1543 entidades.",
    "archivo": "colonias_cdmx.gpkg",
    "formato": "GeoPackage",
    "capas": [
      {
        "nombre_capa": "catalogoColonias",
        "tipo_geometria": "Polygon",
        "numero_entidades": 1543,
        "crs": "PROJCS[\"WGS 84 / UTM zone 14N\",GEOGCS[\"WGS 84\",DATUM[\"WGS_1984\",SPHEROID[\"WGS 84\",6378137,298.257223563,AUTHORITY[\"EPSG\",\"7030\"]],AUTHORITY[\"EPSG\",\"6326\"]],PRIMEM[\"Greenwich\",0,AUTHORITY[\"EPSG\",\"8901\"]],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]],AUTHORITY[\"EPSG\",\"4326\"]],PROJECTION[\"Transverse_Mercator\"],PARAMETER[\"latitude_of_origin\",0],PARAMETER[\"central_meridian\",-99],PARAMETER[\"scale_factor\",0.9996],PARAMETER[\"false_easting\",500000],PARAMETER[\"false_northing\",0],UNIT[\"metre\",1,AUTHORITY[\"EPSG\",\"9001\"]],AXIS[\"Easting\",EAST],AXIS[\"Northing\",NORTH],AUTHORITY[\"EPSG\",\"32614\"]]",
        "descripcion": "Representa colonias de la Ciudad de México. Capa geográfica 'catalogoColonias' en formato GeoPackage con geometría tipo Polygon y 1543 entidades.",
        "variables": {
          "cve_ent": {
            "tipo": "str",
            "descripcion": "Clave de entidad federativa."
          },
          "entidad": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: entidad."
          },
          "cve_alc": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: cve_alc."
          },
          "alc": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: alc."
          },
          "cve_col": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: cve_col."
          },
          "colonia": {
            "tipo": "str",
            "descripcion": "Nombre de la colonia."
          },
          "clasif": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: clasif."
          }
        }
      }
    ]
  }}

ruta_json = capa7.with_suffix(".json")

# Guardamos el archivo
with open(ruta_json, "w", encoding="utf-8") as archivo:
    json.dump(metadato, archivo, ensure_ascii=False, indent=4)

# %%
capa8 = ruta_gpkg / "denue_cdmx.gpkg"

metadato= {"denue_cdmx.gpkg": {
    "titulo": "Directorio Estadístico de Unidades Económicas Ciudad de México",
    "fuentes": [
      "Datos abiertos de la Ciudad de México: https://datos.cdmx.gob.mx/dataset/directorio-estadistico-de-unidades-economicas-ciudad-de-mexico"
    ],
    "fecha_descarga": "2026-04-10",
    "licencias": [
      "Español - Creative Commons Attribution 4.0"
    ],
    "descripcion": "Representa unidades económicas del DENUE para la Ciudad de México. Capa geográfica 'unidades_economicas' en formato GeoPackage con geometría tipo Point y 17216 entidades.",
    "archivo": "denue_cdmx.gpkg",
    "formato": "GeoPackage",
    "capas": [
      {
        "nombre_capa": "unidades_economicas",
        "tipo_geometria": "Point",
        "numero_entidades": 17216,
        "crs": "PROJCS[\"WGS 84 / UTM zone 14N\",GEOGCS[\"WGS 84\",DATUM[\"WGS_1984\",SPHEROID[\"WGS 84\",6378137,298.257223563,AUTHORITY[\"EPSG\",\"7030\"]],AUTHORITY[\"EPSG\",\"6326\"]],PRIMEM[\"Greenwich\",0,AUTHORITY[\"EPSG\",\"8901\"]],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]],AUTHORITY[\"EPSG\",\"4326\"]],PROJECTION[\"Transverse_Mercator\"],PARAMETER[\"latitude_of_origin\",0],PARAMETER[\"central_meridian\",-99],PARAMETER[\"scale_factor\",0.9996],PARAMETER[\"false_easting\",500000],PARAMETER[\"false_northing\",0],UNIT[\"metre\",1,AUTHORITY[\"EPSG\",\"9001\"]],AXIS[\"Easting\",EAST],AXIS[\"Northing\",NORTH],AUTHORITY[\"EPSG\",\"32614\"]]",
        "descripcion": "Representa unidades económicas del DENUE para la Ciudad de México. Capa geográfica 'unidades_economicas' en formato GeoPackage con geometría tipo Point y 17216 entidades.",
        "variables": {
          "nmbr_st": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: nmbr_st."
          },
          "rzn_scl": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: rzn_scl."
          },
          "fech_lt": {
            "tipo": "datetime",
            "descripcion": "Variable original del insumo: fech_lt."
          },
          "ctgr_ct": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: ctgr_ct."
          },
          "activdd": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: activdd."
          },
          "prsns_c": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: prsns_c."
          },
          "tp_mprs": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: tp_mprs."
          },
          "tp_cnt_": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: tp_cnt_."
          },
          "cntr_cm": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: cntr_cm."
          },
          "tp_ndd_": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: tp_ndd_."
          },
          "direccn": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: direccn."
          },
          "colonia": {
            "tipo": "str",
            "descripcion": "Nombre de la colonia."
          },
          "alcaldi": {
            "tipo": "str",
            "descripcion": "Nombre de la alcaldía."
          },
          "telefon": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: telefon."
          },
          "crr_lct": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: crr_lct."
          },
          "pagn_wb": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: pagn_wb."
          }
        }
      }
    ]
  }}

ruta_json = capa8.with_suffix(".json")

# Guardamos el archivo
with open(ruta_json, "w", encoding="utf-8") as archivo:
    json.dump(metadato, archivo, ensure_ascii=False, indent=4)

# %%
capa9 = ruta_gpkg / "escuelas_privadas.gpkg"

metadato= {"escuelas_privadas.gpkg": {
    "titulo": "Escuelas Privadas",
    "fuentes": [
      "Datos abiertos de la Ciudad de México: https://datos.cdmx.gob.mx/dataset/escuelas-privadas"
    ],
    "fecha_descarga": "2026-04-10",
    "licencias": [
      "Español - Creative Commons Attribution 4.0"
    ],
    "descripcion": "Representa escuelas privadas. Capa geográfica 'escuelas_privadas' en formato GeoPackage con geometría tipo Point y 3659 entidades.",
    "archivo": "escuelas_privadas.gpkg",
    "formato": "GeoPackage",
    "capas": [
      {
        "nombre_capa": "escuelas_privadas",
        "tipo_geometria": "Point",
        "numero_entidades": 3659,
        "crs": "PROJCS[\"WGS 84 / UTM zone 14N\",GEOGCS[\"WGS 84\",DATUM[\"WGS_1984\",SPHEROID[\"WGS 84\",6378137,298.257223563,AUTHORITY[\"EPSG\",\"7030\"]],AUTHORITY[\"EPSG\",\"6326\"]],PRIMEM[\"Greenwich\",0,AUTHORITY[\"EPSG\",\"8901\"]],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]],AUTHORITY[\"EPSG\",\"4326\"]],PROJECTION[\"Transverse_Mercator\"],PARAMETER[\"latitude_of_origin\",0],PARAMETER[\"central_meridian\",-99],PARAMETER[\"scale_factor\",0.9996],PARAMETER[\"false_easting\",500000],PARAMETER[\"false_northing\",0],UNIT[\"metre\",1,AUTHORITY[\"EPSG\",\"9001\"]],AXIS[\"Easting\",EAST],AXIS[\"Northing\",NORTH],AUTHORITY[\"EPSG\",\"32614\"]]",
        "descripcion": "Representa escuelas privadas. Capa geográfica 'escuelas_privadas' en formato GeoPackage con geometría tipo Point y 3659 entidades.",
        "variables": {
          "nombre": {
            "tipo": "str",
            "descripcion": "Nombre del elemento geográfico o registro."
          },
          "nivel": {
            "tipo": "str",
            "descripcion": "Nivel o jerarquía de la infraestructura."
          },
          "colonia": {
            "tipo": "str",
            "descripcion": "Nombre de la colonia."
          },
          "alcaldi": {
            "tipo": "str",
            "descripcion": "Nombre de la alcaldía."
          }
        }
      }
    ]
  }}

ruta_json = capa9.with_suffix(".json")

# Guardamos el archivo
with open(ruta_json, "w", encoding="utf-8") as archivo:
    json.dump(metadato, archivo, ensure_ascii=False, indent=4)

# %%
capa10 = ruta_gpkg / "escuelas_publicas.gpkg"

metadato= {"escuelas_publicas.gpkg": {
    "titulo": "Escuelas Publicas",
    "fuentes": [
      "Datos abiertos de la Ciudad de México: https://datos.cdmx.gob.mx/dataset/escuelas-publicas"
    ],
    "fecha_descarga": "2026-04-10",
    "licencias": [
      "Español - Creative Commons Attribution 4.0"
    ],
    "descripcion": "Representa escuelas públicas. Capa geográfica 'escuelas_publicas' en formato GeoPackage con geometría tipo Point y 2242 entidades.",
    "archivo": "escuelas_publicas.gpkg",
    "formato": "GeoPackage",
    "capas": [
      {
        "nombre_capa": "escuelas_publicas",
        "tipo_geometria": "Point",
        "numero_entidades": 2242,
        "crs": "PROJCS[\"WGS 84 / UTM zone 14N\",GEOGCS[\"WGS 84\",DATUM[\"WGS_1984\",SPHEROID[\"WGS 84\",6378137,298.257223563,AUTHORITY[\"EPSG\",\"7030\"]],AUTHORITY[\"EPSG\",\"6326\"]],PRIMEM[\"Greenwich\",0,AUTHORITY[\"EPSG\",\"8901\"]],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]],AUTHORITY[\"EPSG\",\"4326\"]],PROJECTION[\"Transverse_Mercator\"],PARAMETER[\"latitude_of_origin\",0],PARAMETER[\"central_meridian\",-99],PARAMETER[\"scale_factor\",0.9996],PARAMETER[\"false_easting\",500000],PARAMETER[\"false_northing\",0],UNIT[\"metre\",1,AUTHORITY[\"EPSG\",\"9001\"]],AXIS[\"Easting\",EAST],AXIS[\"Northing\",NORTH],AUTHORITY[\"EPSG\",\"32614\"]]",
        "descripcion": "Representa escuelas públicas. Capa geográfica 'escuelas_publicas' en formato GeoPackage con geometría tipo Point y 2242 entidades.",
        "variables": {
          "nombre": {
            "tipo": "str",
            "descripcion": "Nombre del elemento geográfico o registro."
          },
          "colonia": {
            "tipo": "str",
            "descripcion": "Nombre de la colonia."
          },
          "alcaldia": {
            "tipo": "str",
            "descripcion": "Alcaldía asociada al registro."
          }
        }
      }
    ]
  }}

ruta_json = capa10.with_suffix(".json")

# Guardamos el archivo
with open(ruta_json, "w", encoding="utf-8") as archivo:
    json.dump(metadato, archivo, ensure_ascii=False, indent=4)

# %%
capa11 = ruta_gpkg / "estaciones_metro_limpia.gpkg"

metadato= {"estaciones_metro_limpia.gpkg": {
    "titulo": "Estaciones del Metro procesada",
    "fuentes": [
      "Datos abiertos de la Ciudad de México: https://datos.cdmx.gob.mx/dataset/lineas-y-estaciones-del-metro"
    ],
    "fecha_descarga": "2026-04-10",
    "licencias": [
      "Español - Creative Commons Attribution 4.0"
    ],
    "descripcion": "Representa estaciones del Metro. Capa geográfica 'estaciones_metro_limpia' en formato GeoPackage con geometría tipo 3D Point y 195 entidades.",
    "archivo": "estaciones_metro_limpia.gpkg",
    "formato": "GeoPackage",
    "capas": [
      {
        "nombre_capa": "estaciones_metro_limpia",
        "tipo_geometria": "3D Point",
        "numero_entidades": 195,
        "crs": "GEOGCS[\"WGS 84\",DATUM[\"WGS_1984\",SPHEROID[\"WGS 84\",6378137,298.257223563,AUTHORITY[\"EPSG\",\"7030\"]],AUTHORITY[\"EPSG\",\"6326\"]],PRIMEM[\"Greenwich\",0,AUTHORITY[\"EPSG\",\"8901\"]],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]],AXIS[\"Latitude\",NORTH],AXIS[\"Longitude\",EAST],AUTHORITY[\"EPSG\",\"4326\"]]",
        "descripcion": "Representa estaciones del Metro. Capa geográfica 'estaciones_metro_limpia' en formato GeoPackage con geometría tipo 3D Point y 195 entidades.",
        "variables": {
          "SISTEMA": {
            "tipo": "str",
            "descripcion": "Sistema de transporte o programa al que pertenece el elemento."
          },
          "NOMBRE": {
            "tipo": "str",
            "descripcion": "Nombre del elemento geográfico o registro."
          },
          "LINEA": {
            "tipo": "str",
            "descripcion": "Identificador o nombre de la línea de transporte."
          },
          "TIPO": {
            "tipo": "str",
            "descripcion": "Tipo de elemento o clasificación general."
          },
          "ALCALDIAS": {
            "tipo": "str",
            "descripcion": "Alcaldía o conjunto de alcaldías asociadas al registro."
          }
        }
      }
    ]
  }}

ruta_json = capa11.with_suffix(".json")

# Guardamos el archivo
with open(ruta_json, "w", encoding="utf-8") as archivo:
    json.dump(metadato, archivo, ensure_ascii=False, indent=4)

# %%
capa12 = ruta_gpkg / "estaciones_metrobus.gpkg"

metadato= {"estaciones_metrobus.gpkg": {
    "titulo": "Estaciones del Metrobus",
    "fuentes": [
      "Datos abiertos de la Ciudad de México: https://datos.cdmx.gob.mx/dataset/geolocalizacion-metrobus/resource/66cd5773-d83f-4a80-8c15-8ab34851e046"
    ],
    "fecha_descarga": "2026-04-10",
    "licencias": [
      "Español - Creative Commons Attribution 4.0"
    ],
    "descripcion": "Representa estaciones del Metrobús. Capa geográfica 'estaciones_metrobus' en formato GeoPackage con geometría tipo 3D Point y 324 entidades.",
    "archivo": "estaciones_metrobus.gpkg",
    "formato": "GeoPackage",
    "capas": [
      {
        "nombre_capa": "estaciones_metrobus",
        "tipo_geometria": "3D Point",
        "numero_entidades": 324,
        "crs": "GEOGCS[\"WGS 84\",DATUM[\"WGS_1984\",SPHEROID[\"WGS 84\",6378137,298.257223563,AUTHORITY[\"EPSG\",\"7030\"]],AUTHORITY[\"EPSG\",\"6326\"]],PRIMEM[\"Greenwich\",0,AUTHORITY[\"EPSG\",\"8901\"]],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]],AXIS[\"Latitude\",NORTH],AXIS[\"Longitude\",EAST],AUTHORITY[\"EPSG\",\"4326\"]]",
        "descripcion": "Representa estaciones del Metrobús. Capa geográfica 'estaciones_metrobus' en formato GeoPackage con geometría tipo 3D Point y 324 entidades.",
        "variables": {
          "SISTEMA": {
            "tipo": "str",
            "descripcion": "Sistema de transporte o programa al que pertenece el elemento."
          },
          "NOMBRE": {
            "tipo": "str",
            "descripcion": "Nombre del elemento geográfico o registro."
          },
          "LINEA": {
            "tipo": "str",
            "descripcion": "Identificador o nombre de la línea de transporte."
          },
          "TIPO": {
            "tipo": "str",
            "descripcion": "Tipo de elemento o clasificación general."
          },
          "ALCALDIAS": {
            "tipo": "str",
            "descripcion": "Alcaldía o conjunto de alcaldías asociadas al registro."
          }
        }
      }
    ]
  }}

ruta_json = capa12.with_suffix(".json")

# Guardamos el archivo
with open(ruta_json, "w", encoding="utf-8") as archivo:
    json.dump(metadato, archivo, ensure_ascii=False, indent=4)

# %%
capa13 = ruta_gpkg / "hospitales_cs.gpkg"

metadato= {"hospitales_cs.gpkg": {
    "titulo": "Hospitales y Centros de Salud",
    "fuentes": [
      "Datos abiertos de la Ciudad de México: https://datos.cdmx.gob.mx/dataset/hospitales-y-centros-de-salud"
    ],
    "fecha_descarga": "2026-04-10",
    "licencias": [
      "Español - Creative Commons Attribution 4.0"
    ],
    "descripcion": "Representa hospitales o centros de salud. Capa geográfica 'hospitales_cs' en formato GeoPackage con geometría tipo Point y 27 entidades.",
    "archivo": "hospitales_cs.gpkg",
    "formato": "GeoPackage",
    "capas": [
      {
        "nombre_capa": "hospitales_cs",
        "tipo_geometria": "Point",
        "numero_entidades": 27,
        "crs": "GEOGCS[\"WGS 84\",DATUM[\"WGS_1984\",SPHEROID[\"WGS 84\",6378137,298.257223563,AUTHORITY[\"EPSG\",\"7030\"]],AUTHORITY[\"EPSG\",\"6326\"]],PRIMEM[\"Greenwich\",0,AUTHORITY[\"EPSG\",\"8901\"]],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]],AXIS[\"Latitude\",NORTH],AXIS[\"Longitude\",EAST],AUTHORITY[\"EPSG\",\"4326\"]]",
        "descripcion": "Representa hospitales o centros de salud. Capa geográfica 'hospitales_cs' en formato GeoPackage con geometría tipo Point y 27 entidades.",
        "variables": {
          "id": {
            "tipo": "int32",
            "descripcion": "Identificador del registro."
          },
          "nombre": {
            "tipo": "str",
            "descripcion": "Nombre del elemento geográfico o registro."
          }
        }
      }
    ]
  }}

ruta_json = capa13.with_suffix(".json")

# Guardamos el archivo
with open(ruta_json, "w", encoding="utf-8") as archivo:
    json.dump(metadato, archivo, ensure_ascii=False, indent=4)

# %%
capa14 = ruta_gpkg / "infra_ciclista_limpia.gpkg"

metadato= {"infra_ciclista_limpia.gpkg": {
    "titulo": "Infraestructura Ciclista Procesada",
    "fuentes": [
      "Datos abiertos de la Ciudad de México: https://datos.cdmx.gob.mx/dataset/infraestructura-vial-ciclista"
    ],
    "fecha_descarga": "2026-04-10",
    "licencias": [
      "Español - Creative Commons Attribution 4.0"
    ],
    "descripcion": "Representa infraestructura ciclista. Capa geográfica 'infra_ciclista_limpia' en formato GeoPackage con geometría tipo 3D MultiLineString y 514 entidades.",
    "archivo": "infra_ciclista_limpia.gpkg",
    "formato": "GeoPackage",
    "capas": [
      {
        "nombre_capa": "infra_ciclista_limpia",
        "tipo_geometria": "3D MultiLineString",
        "numero_entidades": 514,
        "crs": "PROJCS[\"WGS 84 / UTM zone 14N\",GEOGCS[\"WGS 84\",DATUM[\"WGS_1984\",SPHEROID[\"WGS 84\",6378137,298.257223563,AUTHORITY[\"EPSG\",\"7030\"]],AUTHORITY[\"EPSG\",\"6326\"]],PRIMEM[\"Greenwich\",0,AUTHORITY[\"EPSG\",\"8901\"]],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]],AUTHORITY[\"EPSG\",\"4326\"]],PROJECTION[\"Transverse_Mercator\"],PARAMETER[\"latitude_of_origin\",0],PARAMETER[\"central_meridian\",-99],PARAMETER[\"scale_factor\",0.9996],PARAMETER[\"false_easting\",500000],PARAMETER[\"false_northing\",0],UNIT[\"metre\",1,AUTHORITY[\"EPSG\",\"9001\"]],AXIS[\"Easting\",EAST],AXIS[\"Northing\",NORTH],AUTHORITY[\"EPSG\",\"32614\"]]",
        "descripcion": "Representa infraestructura ciclista. Capa geográfica 'infra_ciclista_limpia' en formato GeoPackage con geometría tipo 3D MultiLineString y 514 entidades.",
        "variables": {
          "ALCALDIA": {
            "tipo": "str",
            "descripcion": "Alcaldía asociada al registro."
          },
          "TIPO_IC": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: TIPO_IC."
          },
          "TIPO_VIA": {
            "tipo": "str",
            "descripcion": "Tipo de vialidad."
          },
          "TIPO_CONEC": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: TIPO_CONEC."
          },
          "LONG_KM": {
            "tipo": "float",
            "descripcion": "Longitud del tramo en kilómetros."
          }
        }
      }
    ]
  }}

ruta_json = capa14.with_suffix(".json")

# Guardamos el archivo
with open(ruta_json, "w", encoding="utf-8") as archivo:
    json.dump(metadato, archivo, ensure_ascii=False, indent=4)

# %%
capa15 = ruta_gpkg / "infra_vial_ciclista.gpkg"

metadato= {"infra_vial_ciclista.gpkg": {
    "titulo": "Infra Vial Ciclista",
    "fuentes": [
      "Datos abiertos de la Ciudad de México: https://datos.cdmx.gob.mx/dataset/infraestructura-vial-ciclista"
    ],
    "fecha_descarga": "2026-04-10",
    "licencias": [
      "Español - Creative Commons Attribution 4.0"
    ],
    "descripcion": "Representa infraestructura vial ciclista. Capa geográfica 'infraestructura_vial_ciclista' en formato GeoPackage con geometría tipo 3D LineString y 98 entidades.",
    "archivo": "infra_vial_ciclista.gpkg",
    "formato": "GeoPackage",
    "capas": [
      {
        "nombre_capa": "infraestructura_vial_ciclista",
        "tipo_geometria": "3D LineString",
        "numero_entidades": 98,
        "crs": "PROJCS[\"WGS 84 / UTM zone 14N\",GEOGCS[\"WGS 84\",DATUM[\"WGS_1984\",SPHEROID[\"WGS 84\",6378137,298.257223563,AUTHORITY[\"EPSG\",\"7030\"]],AUTHORITY[\"EPSG\",\"6326\"]],PRIMEM[\"Greenwich\",0,AUTHORITY[\"EPSG\",\"8901\"]],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]],AUTHORITY[\"EPSG\",\"4326\"]],PROJECTION[\"Transverse_Mercator\"],PARAMETER[\"latitude_of_origin\",0],PARAMETER[\"central_meridian\",-99],PARAMETER[\"scale_factor\",0.9996],PARAMETER[\"false_easting\",500000],PARAMETER[\"false_northing\",0],UNIT[\"metre\",1,AUTHORITY[\"EPSG\",\"9001\"]],AXIS[\"Easting\",EAST],AXIS[\"Northing\",NORTH],AUTHORITY[\"EPSG\",\"32614\"]]",
        "descripcion": "Representa infraestructura vial ciclista. Capa geográfica 'infraestructura_vial_ciclista' en formato GeoPackage con geometría tipo 3D LineString y 98 entidades.",
        "variables": {
          "ID_TRAMO": {
            "tipo": "int",
            "descripcion": "Variable original del insumo: ID_TRAMO."
          },
          "ID_PROY": {
            "tipo": "int",
            "descripcion": "Variable original del insumo: ID_PROY."
          },
          "NOMBRE": {
            "tipo": "str",
            "descripcion": "Nombre del elemento geográfico o registro."
          },
          "TIPO_IC": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: TIPO_IC."
          },
          "ALCALDIA": {
            "tipo": "str",
            "descripcion": "Alcaldía asociada al registro."
          },
          "VIALIDAD": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VIALIDAD."
          },
          "TIPO_VIA": {
            "tipo": "str",
            "descripcion": "Tipo de vialidad."
          },
          "TIPO_CONEC": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: TIPO_CONEC."
          },
          "ESTADO": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: ESTADO."
          },
          "EJECUTOR": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: EJECUTOR."
          },
          "A_INICIO": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: A_INICIO."
          },
          "A_TERMINO": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: A_TERMINO."
          },
          "LONG_KM": {
            "tipo": "float",
            "descripcion": "Longitud del tramo en kilómetros."
          }
        }
      }
    ]
  }}

ruta_json = capa15.with_suffix(".json")

# Guardamos el archivo
with open(ruta_json, "w", encoding="utf-8") as archivo:
    json.dump(metadato, archivo, ensure_ascii=False, indent=4)

# %%
capa16 = ruta_gpkg / "lineas_metro.gpkg"

metadato= {"lineas_metro.gpkg": {
    "titulo": "Lineas del Metro",
    "fuentes": [
      "Datos abiertos de la Ciudad de México: https://datos.cdmx.gob.mx/dataset/lineas-y-estaciones-del-metro"
    ],
    "fecha_descarga": "2026-04-10",
    "licencias": [
      "Español - Creative Commons Attribution 4.0"
    ],
    "descripcion": "Representa líneas del Metro. Capa geográfica 'lineas_metro' en formato GeoPackage con geometría tipo 3D LineString y 12 entidades.",
    "archivo": "lineas_metro.gpkg",
    "formato": "GeoPackage",
    "capas": [
      {
        "nombre_capa": "lineas_metro",
        "tipo_geometria": "3D LineString",
        "numero_entidades": 12,
        "crs": "PROJCS[\"WGS 84 / UTM zone 14N\",GEOGCS[\"WGS 84\",DATUM[\"WGS_1984\",SPHEROID[\"WGS 84\",6378137,298.257223563,AUTHORITY[\"EPSG\",\"7030\"]],AUTHORITY[\"EPSG\",\"6326\"]],PRIMEM[\"Greenwich\",0,AUTHORITY[\"EPSG\",\"8901\"]],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]],AUTHORITY[\"EPSG\",\"4326\"]],PROJECTION[\"Transverse_Mercator\"],PARAMETER[\"latitude_of_origin\",0],PARAMETER[\"central_meridian\",-99],PARAMETER[\"scale_factor\",0.9996],PARAMETER[\"false_easting\",500000],PARAMETER[\"false_northing\",0],UNIT[\"metre\",1,AUTHORITY[\"EPSG\",\"9001\"]],AXIS[\"Easting\",EAST],AXIS[\"Northing\",NORTH],AUTHORITY[\"EPSG\",\"32614\"]]",
        "descripcion": "Representa líneas del Metro. Capa geográfica 'lineas_metro' en formato GeoPackage con geometría tipo 3D LineString y 12 entidades.",
        "variables": {
          "SISTEMA": {
            "tipo": "str",
            "descripcion": "Sistema de transporte o programa al que pertenece el elemento."
          },
          "LINEA": {
            "tipo": "str",
            "descripcion": "Identificador o nombre de la línea de transporte."
          },
          "RUTA": {
            "tipo": "str",
            "descripcion": "Nombre o identificación de la ruta."
          }
        }
      }
    ]
  }}

ruta_json = capa16.with_suffix(".json")

# Guardamos el archivo
with open(ruta_json, "w", encoding="utf-8") as archivo:
    json.dump(metadato, archivo, ensure_ascii=False, indent=4)

# %%
capa17 = ruta_gpkg / "lineas_metrobus.gpkg"

metadato= {"lineas_metrobus.gpkg": {
    "titulo": "Lineas Metrobus",
    "fuentes": [
      "Datos abiertos de la Ciudad de México: https://datos.cdmx.gob.mx/dataset/geolocalizacion-metrobus/resource/66cd5773-d83f-4a80-8c15-8ab34851e046"
    ],
    "fecha_descarga": "2026-04-10",
    "licencias": [
      "Español - Creative Commons Attribution 4.0"
    ],
    "descripcion": "Representa líneas del Metrobús. Capa geográfica 'lineas_metrobus' en formato GeoPackage con geometría tipo 3D MultiLineString y 64 entidades.",
    "archivo": "lineas_metrobus.gpkg",
    "formato": "GeoPackage",
    "capas": [
      {
        "nombre_capa": "lineas_metrobus",
        "tipo_geometria": "3D MultiLineString",
        "numero_entidades": 64,
        "crs": "GEOGCS[\"WGS 84\",DATUM[\"WGS_1984\",SPHEROID[\"WGS 84\",6378137,298.257223563,AUTHORITY[\"EPSG\",\"7030\"]],AUTHORITY[\"EPSG\",\"6326\"]],PRIMEM[\"Greenwich\",0,AUTHORITY[\"EPSG\",\"8901\"]],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]],AXIS[\"Latitude\",NORTH],AXIS[\"Longitude\",EAST],AUTHORITY[\"EPSG\",\"4326\"]]",
        "descripcion": "Representa líneas del Metrobús. Capa geográfica 'lineas_metrobus' en formato GeoPackage con geometría tipo 3D MultiLineString y 64 entidades.",
        "variables": {
          "SISTEMA": {
            "tipo": "str",
            "descripcion": "Sistema de transporte o programa al que pertenece el elemento."
          },
          "RUTA": {
            "tipo": "str",
            "descripcion": "Nombre o identificación de la ruta."
          },
          "LINEA": {
            "tipo": "str",
            "descripcion": "Identificador o nombre de la línea de transporte."
          }
        }
      }
    ]
  },
  "localidades_cdmx_poblacion.gpkg": {
    "titulo": "Localidades Cdmx Poblacion",
    "fuentes": [
      "Datos abiertos de la Ciudad de México: "
    ],
    "fecha_descarga": "2026-04-10",
    "licencias": [
      "Español - Creative Commons Attribution 4.0"
    ],
    "descripcion": "Representa localidades con variables de población. Capa geográfica 'localidades_cdmx_poblacion' en formato GeoPackage con geometría tipo Point y 634 entidades.",
    "archivo": "localidades_cdmx_poblacion.gpkg",
    "formato": "GeoPackage",
    "capas": [
      {
        "nombre_capa": "localidades_cdmx_poblacion",
        "tipo_geometria": "Point",
        "numero_entidades": 634,
        "crs": "GEOGCS[\"WGS 84\",DATUM[\"WGS_1984\",SPHEROID[\"WGS 84\",6378137,298.257223563,AUTHORITY[\"EPSG\",\"7030\"]],AUTHORITY[\"EPSG\",\"6326\"]],PRIMEM[\"Greenwich\",0,AUTHORITY[\"EPSG\",\"8901\"]],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]],AXIS[\"Latitude\",NORTH],AXIS[\"Longitude\",EAST],AUTHORITY[\"EPSG\",\"4326\"]]",
        "descripcion": "Representa localidades con variables de población. Capa geográfica 'localidades_cdmx_poblacion' en formato GeoPackage con geometría tipo Point y 634 entidades.",
        "variables": {
          "ENTIDAD": {
            "tipo": "int",
            "descripcion": "Variable original del insumo: ENTIDAD."
          },
          "NOM_ENT": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: NOM_ENT."
          },
          "MUN": {
            "tipo": "int",
            "descripcion": "Variable original del insumo: MUN."
          },
          "NOM_MUN": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: NOM_MUN."
          },
          "LOC": {
            "tipo": "int",
            "descripcion": "Variable original del insumo: LOC."
          },
          "NOM_LOC": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: NOM_LOC."
          },
          "LONGITUD": {
            "tipo": "str",
            "descripcion": "Longitud en coordenadas geográficas."
          },
          "LATITUD": {
            "tipo": "str",
            "descripcion": "Latitud en coordenadas geográficas."
          },
          "ALTITUD": {
            "tipo": "float",
            "descripcion": "Variable original del insumo: ALTITUD."
          },
          "POBTOT": {
            "tipo": "int",
            "descripcion": "Población total."
          },
          "POBFEM": {
            "tipo": "int",
            "descripcion": "Población femenina."
          },
          "POBMAS": {
            "tipo": "int",
            "descripcion": "Población masculina."
          },
          "P_0A2": {
            "tipo": "int",
            "descripcion": "Variable original del insumo: P_0A2."
          },
          "P_0A2_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_0A2_F."
          },
          "P_0A2_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_0A2_M."
          },
          "P_3YMAS": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_3YMAS."
          },
          "P_3YMAS_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_3YMAS_F."
          },
          "P_3YMAS_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_3YMAS_M."
          },
          "P_5YMAS": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_5YMAS."
          },
          "P_5YMAS_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_5YMAS_F."
          },
          "P_5YMAS_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_5YMAS_M."
          },
          "P_12YMAS": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_12YMAS."
          },
          "P_12YMAS_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_12YMAS_F."
          },
          "P_12YMAS_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_12YMAS_M."
          },
          "P_15YMAS": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_15YMAS."
          },
          "P_15YMAS_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_15YMAS_F."
          },
          "P_15YMAS_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_15YMAS_M."
          },
          "P_18YMAS": {
            "tipo": "int",
            "descripcion": "Variable original del insumo: P_18YMAS."
          },
          "P_18YMAS_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_18YMAS_F."
          },
          "P_18YMAS_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_18YMAS_M."
          },
          "P_3A5": {
            "tipo": "int",
            "descripcion": "Variable original del insumo: P_3A5."
          },
          "P_3A5_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_3A5_F."
          },
          "P_3A5_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_3A5_M."
          },
          "P_6A11": {
            "tipo": "int",
            "descripcion": "Variable original del insumo: P_6A11."
          },
          "P_6A11_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_6A11_F."
          },
          "P_6A11_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_6A11_M."
          },
          "P_8A14": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_8A14."
          },
          "P_8A14_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_8A14_F."
          },
          "P_8A14_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_8A14_M."
          },
          "P_12A14": {
            "tipo": "int",
            "descripcion": "Variable original del insumo: P_12A14."
          },
          "P_12A14_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_12A14_F."
          },
          "P_12A14_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_12A14_M."
          },
          "P_15A17": {
            "tipo": "int",
            "descripcion": "Variable original del insumo: P_15A17."
          },
          "P_15A17_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_15A17_F."
          },
          "P_15A17_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_15A17_M."
          },
          "P_18A24": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_18A24."
          },
          "P_18A24_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_18A24_F."
          },
          "P_18A24_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_18A24_M."
          },
          "P_15A49_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_15A49_F."
          },
          "P_60YMAS": {
            "tipo": "int",
            "descripcion": "Variable original del insumo: P_60YMAS."
          },
          "P_60YMAS_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_60YMAS_F."
          },
          "P_60YMAS_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_60YMAS_M."
          },
          "REL_H_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: REL_H_M."
          },
          "POB0_14": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: POB0_14."
          },
          "POB15_64": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: POB15_64."
          },
          "POB65_MAS": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: POB65_MAS."
          },
          "P_0A4": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_0A4."
          },
          "P_0A4_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_0A4_F."
          },
          "P_0A4_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_0A4_M."
          },
          "P_5A9": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_5A9."
          },
          "P_5A9_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_5A9_F."
          },
          "P_5A9_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_5A9_M."
          },
          "P_10A14": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_10A14."
          },
          "P_10A14_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_10A14_F."
          },
          "P_10A14_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_10A14_M."
          },
          "P_15A19": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_15A19."
          },
          "P_15A19_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_15A19_F."
          },
          "P_15A19_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_15A19_M."
          },
          "P_20A24": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_20A24."
          },
          "P_20A24_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_20A24_F."
          },
          "P_20A24_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_20A24_M."
          },
          "P_25A29": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_25A29."
          },
          "P_25A29_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_25A29_F."
          },
          "P_25A29_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_25A29_M."
          },
          "P_30A34": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_30A34."
          },
          "P_30A34_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_30A34_F."
          },
          "P_30A34_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_30A34_M."
          },
          "P_35A39": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_35A39."
          },
          "P_35A39_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_35A39_F."
          },
          "P_35A39_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_35A39_M."
          },
          "P_40A44": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_40A44."
          },
          "P_40A44_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_40A44_F."
          },
          "P_40A44_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_40A44_M."
          },
          "P_45A49": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_45A49."
          },
          "P_45A49_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_45A49_F."
          },
          "P_45A49_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_45A49_M."
          },
          "P_50A54": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_50A54."
          },
          "P_50A54_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_50A54_F."
          },
          "P_50A54_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_50A54_M."
          },
          "P_55A59": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_55A59."
          },
          "P_55A59_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_55A59_F."
          },
          "P_55A59_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_55A59_M."
          },
          "P_60A64": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_60A64."
          },
          "P_60A64_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_60A64_F."
          },
          "P_60A64_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_60A64_M."
          },
          "P_65A69": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_65A69."
          },
          "P_65A69_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_65A69_F."
          },
          "P_65A69_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_65A69_M."
          },
          "P_70A74": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_70A74."
          },
          "P_70A74_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_70A74_F."
          },
          "P_70A74_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_70A74_M."
          },
          "P_75A79": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_75A79."
          },
          "P_75A79_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_75A79_F."
          },
          "P_75A79_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_75A79_M."
          },
          "P_80A84": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_80A84."
          },
          "P_80A84_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_80A84_F."
          },
          "P_80A84_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_80A84_M."
          },
          "P_85YMAS": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_85YMAS."
          },
          "P_85YMAS_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_85YMAS_F."
          },
          "P_85YMAS_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P_85YMAS_M."
          },
          "PROM_HNV": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PROM_HNV."
          },
          "PNACENT": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PNACENT."
          },
          "PNACENT_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PNACENT_F."
          },
          "PNACENT_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PNACENT_M."
          },
          "PNACOE": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PNACOE."
          },
          "PNACOE_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PNACOE_F."
          },
          "PNACOE_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PNACOE_M."
          },
          "PRES2015": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PRES2015."
          },
          "PRES2015_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PRES2015_F."
          },
          "PRES2015_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PRES2015_M."
          },
          "PRESOE15": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PRESOE15."
          },
          "PRESOE15_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PRESOE15_F."
          },
          "PRESOE15_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PRESOE15_M."
          },
          "P3YM_HLI": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P3YM_HLI."
          },
          "P3YM_HLI_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P3YM_HLI_F."
          },
          "P3YM_HLI_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P3YM_HLI_M."
          },
          "P3HLINHE": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P3HLINHE."
          },
          "P3HLINHE_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P3HLINHE_F."
          },
          "P3HLINHE_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P3HLINHE_M."
          },
          "P3HLI_HE": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P3HLI_HE."
          },
          "P3HLI_HE_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P3HLI_HE_F."
          },
          "P3HLI_HE_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P3HLI_HE_M."
          },
          "P5_HLI": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P5_HLI."
          },
          "P5_HLI_NHE": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P5_HLI_NHE."
          },
          "P5_HLI_HE": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P5_HLI_HE."
          },
          "PHOG_IND": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PHOG_IND."
          },
          "POB_AFRO": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: POB_AFRO."
          },
          "POB_AFRO_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: POB_AFRO_F."
          },
          "POB_AFRO_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: POB_AFRO_M."
          },
          "PCON_DISC": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PCON_DISC."
          },
          "PCDISC_MOT": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PCDISC_MOT."
          },
          "PCDISC_VIS": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PCDISC_VIS."
          },
          "PCDISC_LENG": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PCDISC_LENG."
          },
          "PCDISC_AUD": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PCDISC_AUD."
          },
          "PCDISC_MOT2": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PCDISC_MOT2."
          },
          "PCDISC_MEN": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PCDISC_MEN."
          },
          "PCON_LIMI": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PCON_LIMI."
          },
          "PCLIM_CSB": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PCLIM_CSB."
          },
          "PCLIM_VIS": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PCLIM_VIS."
          },
          "PCLIM_HACO": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PCLIM_HACO."
          },
          "PCLIM_OAUD": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PCLIM_OAUD."
          },
          "PCLIM_MOT2": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PCLIM_MOT2."
          },
          "PCLIM_RE_CO": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PCLIM_RE_CO."
          },
          "PCLIM_PMEN": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PCLIM_PMEN."
          },
          "PSIND_LIM": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PSIND_LIM."
          },
          "P3A5_NOA": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P3A5_NOA."
          },
          "P3A5_NOA_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P3A5_NOA_F."
          },
          "P3A5_NOA_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P3A5_NOA_M."
          },
          "P6A11_NOA": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P6A11_NOA."
          },
          "P6A11_NOAF": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P6A11_NOAF."
          },
          "P6A11_NOAM": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P6A11_NOAM."
          },
          "P12A14NOA": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P12A14NOA."
          },
          "P12A14NOAF": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P12A14NOAF."
          },
          "P12A14NOAM": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P12A14NOAM."
          },
          "P15A17A": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P15A17A."
          },
          "P15A17A_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P15A17A_F."
          },
          "P15A17A_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P15A17A_M."
          },
          "P18A24A": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P18A24A."
          },
          "P18A24A_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P18A24A_F."
          },
          "P18A24A_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P18A24A_M."
          },
          "P8A14AN": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P8A14AN."
          },
          "P8A14AN_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P8A14AN_F."
          },
          "P8A14AN_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P8A14AN_M."
          },
          "P15YM_AN": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P15YM_AN."
          },
          "P15YM_AN_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P15YM_AN_F."
          },
          "P15YM_AN_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P15YM_AN_M."
          },
          "P15YM_SE": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P15YM_SE."
          },
          "P15YM_SE_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P15YM_SE_F."
          },
          "P15YM_SE_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P15YM_SE_M."
          },
          "P15PRI_IN": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P15PRI_IN."
          },
          "P15PRI_INF": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P15PRI_INF."
          },
          "P15PRI_INM": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P15PRI_INM."
          },
          "P15PRI_CO": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P15PRI_CO."
          },
          "P15PRI_COF": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P15PRI_COF."
          },
          "P15PRI_COM": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P15PRI_COM."
          },
          "P15SEC_IN": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P15SEC_IN."
          },
          "P15SEC_INF": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P15SEC_INF."
          },
          "P15SEC_INM": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P15SEC_INM."
          },
          "P15SEC_CO": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P15SEC_CO."
          },
          "P15SEC_COF": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P15SEC_COF."
          },
          "P15SEC_COM": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P15SEC_COM."
          },
          "P18YM_PB": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P18YM_PB."
          },
          "P18YM_PB_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P18YM_PB_F."
          },
          "P18YM_PB_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P18YM_PB_M."
          },
          "GRAPROES": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: GRAPROES."
          },
          "GRAPROES_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: GRAPROES_F."
          },
          "GRAPROES_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: GRAPROES_M."
          },
          "PEA": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PEA."
          },
          "PEA_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PEA_F."
          },
          "PEA_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PEA_M."
          },
          "PE_INAC": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PE_INAC."
          },
          "PE_INAC_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PE_INAC_F."
          },
          "PE_INAC_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PE_INAC_M."
          },
          "POCUPADA": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: POCUPADA."
          },
          "POCUPADA_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: POCUPADA_F."
          },
          "POCUPADA_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: POCUPADA_M."
          },
          "PDESOCUP": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PDESOCUP."
          },
          "PDESOCUP_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PDESOCUP_F."
          },
          "PDESOCUP_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PDESOCUP_M."
          },
          "PSINDER": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PSINDER."
          },
          "PDER_SS": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PDER_SS."
          },
          "PDER_IMSS": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PDER_IMSS."
          },
          "PDER_ISTE": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PDER_ISTE."
          },
          "PDER_ISTEE": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PDER_ISTEE."
          },
          "PAFIL_PDOM": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PAFIL_PDOM."
          },
          "PDER_SEGP": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PDER_SEGP."
          },
          "PDER_IMSSB": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PDER_IMSSB."
          },
          "PAFIL_IPRIV": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PAFIL_IPRIV."
          },
          "PAFIL_OTRAI": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PAFIL_OTRAI."
          },
          "P12YM_SOLT": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P12YM_SOLT."
          },
          "P12YM_CASA": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P12YM_CASA."
          },
          "P12YM_SEPA": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: P12YM_SEPA."
          },
          "PCATOLICA": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PCATOLICA."
          },
          "PRO_CRIEVA": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PRO_CRIEVA."
          },
          "POTRAS_REL": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: POTRAS_REL."
          },
          "PSIN_RELIG": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PSIN_RELIG."
          },
          "TOTHOG": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: TOTHOG."
          },
          "HOGJEF_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: HOGJEF_F."
          },
          "HOGJEF_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: HOGJEF_M."
          },
          "POBHOG": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: POBHOG."
          },
          "PHOGJEF_F": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PHOGJEF_F."
          },
          "PHOGJEF_M": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PHOGJEF_M."
          },
          "VIVTOT": {
            "tipo": "int",
            "descripcion": "Variable original del insumo: VIVTOT."
          },
          "TVIVHAB": {
            "tipo": "int",
            "descripcion": "Variable original del insumo: TVIVHAB."
          },
          "TVIVPAR": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: TVIVPAR."
          },
          "VIVPAR_HAB": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VIVPAR_HAB."
          },
          "VIVPARH_CV": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VIVPARH_CV."
          },
          "TVIVPARHAB": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: TVIVPARHAB."
          },
          "VIVPAR_DES": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VIVPAR_DES."
          },
          "VIVPAR_UT": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VIVPAR_UT."
          },
          "OCUPVIVPAR": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: OCUPVIVPAR."
          },
          "PROM_OCUP": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PROM_OCUP."
          },
          "PRO_OCUP_C": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PRO_OCUP_C."
          },
          "VPH_PISODT": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VPH_PISODT."
          },
          "VPH_PISOTI": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VPH_PISOTI."
          },
          "VPH_1DOR": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VPH_1DOR."
          },
          "VPH_2YMASD": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VPH_2YMASD."
          },
          "VPH_1CUART": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VPH_1CUART."
          },
          "VPH_2CUART": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VPH_2CUART."
          },
          "VPH_3YMASC": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VPH_3YMASC."
          },
          "VPH_C_ELEC": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VPH_C_ELEC."
          },
          "VPH_S_ELEC": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VPH_S_ELEC."
          },
          "VPH_AGUADV": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VPH_AGUADV."
          },
          "VPH_AEASP": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VPH_AEASP."
          },
          "VPH_AGUAFV": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VPH_AGUAFV."
          },
          "VPH_TINACO": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VPH_TINACO."
          },
          "VPH_CISTER": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VPH_CISTER."
          },
          "VPH_EXCSA": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VPH_EXCSA."
          },
          "VPH_LETR": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VPH_LETR."
          },
          "VPH_DRENAJ": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VPH_DRENAJ."
          },
          "VPH_NODREN": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VPH_NODREN."
          },
          "VPH_C_SERV": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VPH_C_SERV."
          },
          "VPH_NDEAED": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VPH_NDEAED."
          },
          "VPH_DSADMA": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VPH_DSADMA."
          },
          "VPH_NDACMM": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VPH_NDACMM."
          },
          "VPH_SNBIEN": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VPH_SNBIEN."
          },
          "VPH_REFRI": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VPH_REFRI."
          },
          "VPH_LAVAD": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VPH_LAVAD."
          },
          "VPH_HMICRO": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VPH_HMICRO."
          },
          "VPH_AUTOM": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VPH_AUTOM."
          },
          "VPH_MOTO": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VPH_MOTO."
          },
          "VPH_BICI": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VPH_BICI."
          },
          "VPH_RADIO": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VPH_RADIO."
          },
          "VPH_TV": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VPH_TV."
          },
          "VPH_PC": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VPH_PC."
          },
          "VPH_TELEF": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VPH_TELEF."
          },
          "VPH_CEL": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VPH_CEL."
          },
          "VPH_INTER": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VPH_INTER."
          },
          "VPH_STVP": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VPH_STVP."
          },
          "VPH_SPMVPI": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VPH_SPMVPI."
          },
          "VPH_CVJ": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VPH_CVJ."
          },
          "VPH_SINRTV": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VPH_SINRTV."
          },
          "VPH_SINLTC": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VPH_SINLTC."
          },
          "VPH_SINCINT": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VPH_SINCINT."
          },
          "VPH_SINTIC": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VPH_SINTIC."
          },
          "TAMLOC": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: TAMLOC."
          },
          "latDecimal": {
            "tipo": "float",
            "descripcion": "Variable original del insumo: latDecimal."
          },
          "lonDecimal": {
            "tipo": "float",
            "descripcion": "Variable original del insumo: lonDecimal."
          }
        }
      }
    ]
  }}

ruta_json = capa17.with_suffix(".json")

# Guardamos el archivo
with open(ruta_json, "w", encoding="utf-8") as archivo:
    json.dump(metadato, archivo, ensure_ascii=False, indent=4)

# %%
capa18 = ruta_gpkg / "manzanas_cdmx_poblacion.gpkg"

metadato= {"manzanas_cdmx_poblacion.gpkg": {
    "titulo": "Población por Manzanas en la Ciudad de México",
    "fuentes": [
      "Creación propia a partir del cruce de población y manzadas en datos abiertos de INEGI"
    ],
    "fecha_descarga": "2026-04-10",
    "licencias": [
      "Español - Creative Commons Attribution 4.0"
    ],
    "descripcion": "Representa manzanas con variables de población. Capa geográfica 'manzanas_cdmx_poblacion' en formato GeoPackage con geometría tipo Polygon y 63174 entidades.",
    "archivo": "manzanas_cdmx_poblacion.gpkg",
    "formato": "GeoPackage",
    "capas": [
      {
        "nombre_capa": "manzanas_cdmx_poblacion",
        "tipo_geometria": "Polygon",
        "numero_entidades": 63174,
        "crs": "PROJCS[\"WGS 84 / UTM zone 14N\",GEOGCS[\"WGS 84\",DATUM[\"WGS_1984\",SPHEROID[\"WGS 84\",6378137,298.257223563,AUTHORITY[\"EPSG\",\"7030\"]],AUTHORITY[\"EPSG\",\"6326\"]],PRIMEM[\"Greenwich\",0,AUTHORITY[\"EPSG\",\"8901\"]],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]],AUTHORITY[\"EPSG\",\"4326\"]],PROJECTION[\"Transverse_Mercator\"],PARAMETER[\"latitude_of_origin\",0],PARAMETER[\"central_meridian\",-99],PARAMETER[\"scale_factor\",0.9996],PARAMETER[\"false_easting\",500000],PARAMETER[\"false_northing\",0],UNIT[\"metre\",1,AUTHORITY[\"EPSG\",\"9001\"]],AXIS[\"Easting\",EAST],AXIS[\"Northing\",NORTH],AUTHORITY[\"EPSG\",\"32614\"]]",
        "descripcion": "Representa manzanas con variables de población. Capa geográfica 'manzanas_cdmx_poblacion' en formato GeoPackage con geometría tipo Polygon y 63174 entidades.",
        "variables": {
          "CVEGEO": {
            "tipo": "str",
            "descripcion": "Clave geoestadística."
          },
          "CVE_ENT": {
            "tipo": "str",
            "descripcion": "Clave de entidad federativa."
          },
          "CVE_MUN": {
            "tipo": "str",
            "descripcion": "Clave de municipio o demarcación."
          },
          "CVE_LOC": {
            "tipo": "str",
            "descripcion": "Clave de localidad."
          },
          "CVE_AGEB": {
            "tipo": "str",
            "descripcion": "Clave de AGEB."
          },
          "CVE_MZA": {
            "tipo": "str",
            "descripcion": "Clave de manzana."
          },
          "AMBITO": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: AMBITO."
          },
          "TIPOMZA": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: TIPOMZA."
          },
          "ClaveMan": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: ClaveMan."
          },
          "POBTOT": {
            "tipo": "int",
            "descripcion": "Población total."
          },
          "POBFEM": {
            "tipo": "float",
            "descripcion": "Población femenina."
          },
          "POBMAS": {
            "tipo": "float",
            "descripcion": "Población masculina."
          },
          "P_0A2": {
            "tipo": "float",
            "descripcion": "Variable original del insumo: P_0A2."
          },
          "P_3A5": {
            "tipo": "float",
            "descripcion": "Variable original del insumo: P_3A5."
          },
          "P_6A11": {
            "tipo": "float",
            "descripcion": "Variable original del insumo: P_6A11."
          },
          "P_12A14": {
            "tipo": "float",
            "descripcion": "Variable original del insumo: P_12A14."
          },
          "P_15A17": {
            "tipo": "float",
            "descripcion": "Variable original del insumo: P_15A17."
          },
          "P_18A24": {
            "tipo": "float",
            "descripcion": "Variable original del insumo: P_18A24."
          },
          "P_60YMAS": {
            "tipo": "float",
            "descripcion": "Variable original del insumo: P_60YMAS."
          }
        }
      }
    ]
  }}

ruta_json = capa18.with_suffix(".json")

# Guardamos el archivo
with open(ruta_json, "w", encoding="utf-8") as archivo:
    json.dump(metadato, archivo, ensure_ascii=False, indent=4)

# %%
capa19 = ruta_gpkg / "rnc_vial_cdmx.gpkg"

metadato= {"rnc_vial_cdmx.gpkg": {
    "titulo": "Rnc Vial Cdmx",
    "fuentes": [
      "Creación propia a partir del recorte de la Red Nacional de Caminos - Instituto Mexicano del transporte"
    ],
    "fecha_descarga": "2026-04-10",
    "licencias": [
      "Español - Creative Commons Attribution 4.0"
    ],
    "descripcion": "Representa red nacional de caminos o red vial en la Ciudad de México. Capa geográfica 'rnc_vial_cdmx' en formato GeoPackage con geometría tipo MultiLineString y 113728 entidades.",
    "archivo": "rnc_vial_cdmx.gpkg",
    "formato": "GeoPackage",
    "capas": [
      {
        "nombre_capa": "rnc_vial_cdmx",
        "tipo_geometria": "MultiLineString",
        "numero_entidades": 113728,
        "crs": "PROJCS[\"WGS 84 / UTM zone 14N\",GEOGCS[\"WGS 84\",DATUM[\"WGS_1984\",SPHEROID[\"WGS 84\",6378137,298.257223563,AUTHORITY[\"EPSG\",\"7030\"]],AUTHORITY[\"EPSG\",\"6326\"]],PRIMEM[\"Greenwich\",0,AUTHORITY[\"EPSG\",\"8901\"]],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]],AUTHORITY[\"EPSG\",\"4326\"]],PROJECTION[\"Transverse_Mercator\"],PARAMETER[\"latitude_of_origin\",0],PARAMETER[\"central_meridian\",-99],PARAMETER[\"scale_factor\",0.9996],PARAMETER[\"false_easting\",500000],PARAMETER[\"false_northing\",0],UNIT[\"metre\",1,AUTHORITY[\"EPSG\",\"9001\"]],AXIS[\"Easting\",EAST],AXIS[\"Northing\",NORTH],AUTHORITY[\"EPSG\",\"32614\"]]",
        "descripcion": "Representa red nacional de caminos o red vial en la Ciudad de México. Capa geográfica 'rnc_vial_cdmx' en formato GeoPackage con geometría tipo MultiLineString y 113728 entidades.",
        "variables": {
          "ID_RED": {
            "tipo": "int32",
            "descripcion": "Variable original del insumo: ID_RED."
          },
          "TIPO_VIAL": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: TIPO_VIAL."
          },
          "NOMBRE": {
            "tipo": "str",
            "descripcion": "Nombre del elemento geográfico o registro."
          },
          "CODIGO": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: CODIGO."
          },
          "COND_PAV": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: COND_PAV."
          },
          "RECUBRI": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: RECUBRI."
          },
          "CARRILES": {
            "tipo": "str",
            "descripcion": "Número de carriles."
          },
          "ESTATUS": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: ESTATUS."
          },
          "CONDICION": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: CONDICION."
          },
          "NIVEL": {
            "tipo": "int16",
            "descripcion": "Nivel o jerarquía de la infraestructura."
          },
          "PEAJE": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: PEAJE."
          },
          "ADMINISTRA": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: ADMINISTRA."
          },
          "JURISDI": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: JURISDI."
          },
          "CIRCULA": {
            "tipo": "str",
            "descripcion": "Sentido o condición de circulación."
          },
          "ESCALA_VIS": {
            "tipo": "int32",
            "descripcion": "Variable original del insumo: ESCALA_VIS."
          },
          "VELOCIDAD": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: VELOCIDAD."
          },
          "UNION_INI": {
            "tipo": "int32",
            "descripcion": "Variable original del insumo: UNION_INI."
          },
          "UNION_FIN": {
            "tipo": "int32",
            "descripcion": "Variable original del insumo: UNION_FIN."
          },
          "LONGITUD": {
            "tipo": "float",
            "descripcion": "Longitud en coordenadas geográficas."
          },
          "ANCHO": {
            "tipo": "float",
            "descripcion": "Variable original del insumo: ANCHO."
          },
          "FECHA_ACT": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: FECHA_ACT."
          },
          "CALIREPR": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: CALIREPR."
          },
          "cat_Vel": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: cat_Vel."
          },
          "cat_Vel_Num": {
            "tipo": "int32",
            "descripcion": "Variable original del insumo: cat_Vel_Num."
          }
        }
      }
    ]
  }}

ruta_json = capa19.with_suffix(".json")

# Guardamos el archivo
with open(ruta_json, "w", encoding="utf-8") as archivo:
    json.dump(metadato, archivo, ensure_ascii=False, indent=4)

# %%
capa20 = ruta_gpkg / "rp_WifiCDMX.gpkg"

metadato= {"rp_WifiCDMX.gpkg": {
    "titulo": "Puntos de acceso a internet gratuito",
    "fuentes": [
      "Integración de puntos de acceso WiFi obtenida en datos abiertos de la Ciudad de México: https://datos.cdmx.gob.mx/dataset/puntos-de-acceso-wifi-en-la-cdmx"
    ],
    "fecha_descarga": "2026-04-10",
    "licencias": [
      "Español - Creative Commons Attribution 4.0"
    ],
    "descripcion": "Representa puntos del programa WiFi CDMX. Capa geográfica 'rp_WifiCDMX' en formato GeoPackage con geometría tipo Point y 70419 entidades.",
    "archivo": "rp_WifiCDMX.gpkg",
    "formato": "GeoPackage",
    "capas": [
      {
        "nombre_capa": "rp_WifiCDMX",
        "tipo_geometria": "Point",
        "numero_entidades": 70419,
        "crs": "PROJCS[\"WGS 84 / UTM zone 14N\",GEOGCS[\"WGS 84\",DATUM[\"WGS_1984\",SPHEROID[\"WGS 84\",6378137,298.257223563,AUTHORITY[\"EPSG\",\"7030\"]],AUTHORITY[\"EPSG\",\"6326\"]],PRIMEM[\"Greenwich\",0,AUTHORITY[\"EPSG\",\"8901\"]],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]],AUTHORITY[\"EPSG\",\"4326\"]],PROJECTION[\"Transverse_Mercator\"],PARAMETER[\"latitude_of_origin\",0],PARAMETER[\"central_meridian\",-99],PARAMETER[\"scale_factor\",0.9996],PARAMETER[\"false_easting\",500000],PARAMETER[\"false_northing\",0],UNIT[\"metre\",1,AUTHORITY[\"EPSG\",\"9001\"]],AXIS[\"Easting\",EAST],AXIS[\"Northing\",NORTH],AUTHORITY[\"EPSG\",\"32614\"]]",
        "descripcion": "Representa puntos del programa WiFi CDMX. Capa geográfica 'rp_WifiCDMX' en formato GeoPackage con geometría tipo Point y 70419 entidades.",
        "variables": {
          "id": {
            "tipo": "str",
            "descripcion": "Identificador del registro."
          },
          "programa": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: programa."
          },
          "latitud": {
            "tipo": "str",
            "descripcion": "Latitud en coordenadas geográficas."
          },
          "longitud": {
            "tipo": "str",
            "descripcion": "Longitud en coordenadas geográficas."
          },
          "alcaldia": {
            "tipo": "str",
            "descripcion": "Alcaldía asociada al registro."
          }
        }
      }
    ]
  }}

ruta_json = capa20.with_suffix(".json")

# Guardamos el archivo
with open(ruta_json, "w", encoding="utf-8") as archivo:
    json.dump(metadato, archivo, ensure_ascii=False, indent=4)

# %%
capa21 = ruta_gpkg / "rtp_lineas.gpkg"

metadato= {"rtp_lineas.gpkg": {
    "titulo": "Rutas de la Red de Transporte Público de la Ciudad de México",
    "fuentes": [
      "Datos abiertos de la Ciudad de México: https://datos.cdmx.gob.mx/dataset/rutas-de-rtp/resource/5a8836cf-02fc-4d13-b61a-6d12da551e81"
    ],
    "fecha_descarga": "2026-04-10",
    "licencias": [
      "Español - Creative Commons Attribution 4.0"
    ],
    "descripcion": "Representa líneas o rutas de RTP. Capa geográfica 'rtp_lineas' en formato GeoPackage con geometría tipo 3D LineString y 200 entidades.",
    "archivo": "rtp_lineas.gpkg",
    "formato": "GeoPackage",
    "capas": [
      {
        "nombre_capa": "rtp_lineas",
        "tipo_geometria": "3D LineString",
        "numero_entidades": 200,
        "crs": "GEOGCS[\"WGS 84\",DATUM[\"WGS_1984\",SPHEROID[\"WGS 84\",6378137,298.257223563,AUTHORITY[\"EPSG\",\"7030\"]],AUTHORITY[\"EPSG\",\"6326\"]],PRIMEM[\"Greenwich\",0,AUTHORITY[\"EPSG\",\"8901\"]],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]],AXIS[\"Latitude\",NORTH],AXIS[\"Longitude\",EAST],AUTHORITY[\"EPSG\",\"4326\"]]",
        "descripcion": "Representa líneas o rutas de RTP. Capa geográfica 'rtp_lineas' en formato GeoPackage con geometría tipo 3D LineString y 200 entidades.",
        "variables": {
          "NOMBRE": {
            "tipo": "str",
            "descripcion": "Nombre del elemento geográfico o registro."
          },
          "SISTEMA": {
            "tipo": "str",
            "descripcion": "Sistema de transporte o programa al que pertenece el elemento."
          },
          "RUTA": {
            "tipo": "str",
            "descripcion": "Nombre o identificación de la ruta."
          },
          "ORIGEN": {
            "tipo": "str",
            "descripcion": "Origen de la ruta o trayecto."
          },
          "DESTINO": {
            "tipo": "str",
            "descripcion": "Destino de la ruta o trayecto."
          }
        }
      }
    ]
  }}

ruta_json = capa21.with_suffix(".json")

# Guardamos el archivo
with open(ruta_json, "w", encoding="utf-8") as archivo:
    json.dump(metadato, archivo, ensure_ascii=False, indent=4)

# %%
capa22 = ruta_gpkg / "rtp_paradas.gpkg"

metadato= {"rtp_paradas.gpkg": {
    "titulo": "Paradas de la Red de Transporte Público de la Ciudad de México",
    "fuentes": [
      "Datos abiertos de la Ciudad de México: https://datos.cdmx.gob.mx/dataset/rutas-de-rtp/resource/5a8836cf-02fc-4d13-b61a-6d12da551e81"
    ],
    "fecha_descarga": "2026-04-10",
    "licencias": [
      "Español - Creative Commons Attribution 4.0"
    ],
    "descripcion": "Representa paradas de RTP. Capa geográfica 'rtp_paradas' en formato GeoPackage con geometría tipo 3D Point y 8132 entidades.",
    "archivo": "rtp_paradas.gpkg",
    "formato": "GeoPackage",
    "capas": [
      {
        "nombre_capa": "rtp_paradas",
        "tipo_geometria": "3D Point",
        "numero_entidades": 8132,
        "crs": "GEOGCS[\"WGS 84\",DATUM[\"WGS_1984\",SPHEROID[\"WGS 84\",6378137,298.257223563,AUTHORITY[\"EPSG\",\"7030\"]],AUTHORITY[\"EPSG\",\"6326\"]],PRIMEM[\"Greenwich\",0,AUTHORITY[\"EPSG\",\"8901\"]],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]],AXIS[\"Latitude\",NORTH],AXIS[\"Longitude\",EAST],AUTHORITY[\"EPSG\",\"4326\"]]",
        "descripcion": "Representa paradas de RTP. Capa geográfica 'rtp_paradas' en formato GeoPackage con geometría tipo 3D Point y 8132 entidades.",
        "variables": {
          "RUTA": {
            "tipo": "str",
            "descripcion": "Nombre o identificación de la ruta."
          },
          "SENTIDO": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: SENTIDO."
          },
          "ORIG_DEST": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: ORIG_DEST."
          },
          "SISTEMA": {
            "tipo": "str",
            "descripcion": "Sistema de transporte o programa al que pertenece el elemento."
          }
        }
      }
    ]
  }}

ruta_json = capa22.with_suffix(".json")

# Guardamos el archivo
with open(ruta_json, "w", encoding="utf-8") as archivo:
    json.dump(metadato, archivo, ensure_ascii=False, indent=4)

# %%
capa23 = ruta_gpkg / "tp_concesionado.gpkg"

metadato= {"tp_concesionado.gpkg": {
    "titulo": "Rutas y corredores del transporte público concesionado",
    "fuentes": [
      "Datos abiertos de la Ciudad de México: https://datos.cdmx.gob.mx/dataset/rutas-y-corredores-del-transporte-publico-concesionado-2"
    ],
    "fecha_descarga": "2026-04-10",
    "licencias": [
      "Español - Creative Commons Attribution 4.0"
    ],
    "descripcion": "Representa rutas de transporte concesionado. Capa geográfica 'tp_concesionado' en formato GeoPackage con geometría tipo 3D MultiLineString y 995 entidades.",
    "archivo": "tp_concesionado.gpkg",
    "formato": "GeoPackage",
    "capas": [
      {
        "nombre_capa": "tp_concesionado",
        "tipo_geometria": "3D MultiLineString",
        "numero_entidades": 995,
        "crs": "PROJCS[\"WGS 84 / UTM zone 14N\",GEOGCS[\"WGS 84\",DATUM[\"WGS_1984\",SPHEROID[\"WGS 84\",6378137,298.257223563,AUTHORITY[\"EPSG\",\"7030\"]],AUTHORITY[\"EPSG\",\"6326\"]],PRIMEM[\"Greenwich\",0,AUTHORITY[\"EPSG\",\"8901\"]],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]],AUTHORITY[\"EPSG\",\"4326\"]],PROJECTION[\"Transverse_Mercator\"],PARAMETER[\"latitude_of_origin\",0],PARAMETER[\"central_meridian\",-99],PARAMETER[\"scale_factor\",0.9996],PARAMETER[\"false_easting\",500000],PARAMETER[\"false_northing\",0],UNIT[\"metre\",1,AUTHORITY[\"EPSG\",\"9001\"]],AXIS[\"Easting\",EAST],AXIS[\"Northing\",NORTH],AUTHORITY[\"EPSG\",\"32614\"]]",
        "descripcion": "Representa rutas de transporte concesionado. Capa geográfica 'tp_concesionado' en formato GeoPackage con geometría tipo 3D MultiLineString y 995 entidades.",
        "variables": {
          "SISTEMA": {
            "tipo": "str",
            "descripcion": "Sistema de transporte o programa al que pertenece el elemento."
          },
          "RUTA": {
            "tipo": "str",
            "descripcion": "Nombre o identificación de la ruta."
          },
          "RAMAL": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: RAMAL."
          }
        }
      }
    ]
  }}

ruta_json = capa23.with_suffix(".json")

# Guardamos el archivo
with open(ruta_json, "w", encoding="utf-8") as archivo:
    json.dump(metadato, archivo, ensure_ascii=False, indent=4)

# %%
capa24 = ruta_gpkg / "tren_ligero_estaciones.gpkg"

metadato= {"tren_ligero_estaciones.gpkg": {
    "titulo": "Ubicación de estaciones/paradas del Servicio de Transportes Eléctricos",
    "fuentes": [
      "Datos abiertos de la Ciudad de México: https://datos.cdmx.gob.mx/id/dataset/geolocalizacion-de-lineas-y-estaciones-paradas-del-servicio-de-transportes-electricos"
    ],
    "fecha_descarga": "2026-04-10",
    "licencias": [
      "Español - Creative Commons Attribution 4.0"
    ],
    "descripcion": "Representa estaciones del Tren Ligero. Capa geográfica 'tren_ligero_estaciones' en formato GeoPackage con geometría tipo 3D Point y 18 entidades.",
    "archivo": "tren_ligero_estaciones.gpkg",
    "formato": "GeoPackage",
    "capas": [
      {
        "nombre_capa": "tren_ligero_estaciones",
        "tipo_geometria": "3D Point",
        "numero_entidades": 18,
        "crs": "PROJCS[\"WGS 84 / UTM zone 14N\",GEOGCS[\"WGS 84\",DATUM[\"WGS_1984\",SPHEROID[\"WGS 84\",6378137,298.257223563,AUTHORITY[\"EPSG\",\"7030\"]],AUTHORITY[\"EPSG\",\"6326\"]],PRIMEM[\"Greenwich\",0,AUTHORITY[\"EPSG\",\"8901\"]],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]],AUTHORITY[\"EPSG\",\"4326\"]],PROJECTION[\"Transverse_Mercator\"],PARAMETER[\"latitude_of_origin\",0],PARAMETER[\"central_meridian\",-99],PARAMETER[\"scale_factor\",0.9996],PARAMETER[\"false_easting\",500000],PARAMETER[\"false_northing\",0],UNIT[\"metre\",1,AUTHORITY[\"EPSG\",\"9001\"]],AXIS[\"Easting\",EAST],AXIS[\"Northing\",NORTH],AUTHORITY[\"EPSG\",\"32614\"]]",
        "descripcion": "Representa estaciones del Tren Ligero. Capa geográfica 'tren_ligero_estaciones' en formato GeoPackage con geometría tipo 3D Point y 18 entidades.",
        "variables": {
          "SISTEMA": {
            "tipo": "str",
            "descripcion": "Sistema de transporte o programa al que pertenece el elemento."
          },
          "NOMBRE": {
            "tipo": "str",
            "descripcion": "Nombre del elemento geográfico o registro."
          },
          "LINEA": {
            "tipo": "str",
            "descripcion": "Identificador o nombre de la línea de transporte."
          },
          "TIPO": {
            "tipo": "str",
            "descripcion": "Tipo de elemento o clasificación general."
          },
          "ALCALDIAS": {
            "tipo": "str",
            "descripcion": "Alcaldía o conjunto de alcaldías asociadas al registro."
          }
        }
      }
    ]
  }}

ruta_json = capa24.with_suffix(".json")

# Guardamos el archivo
with open(ruta_json, "w", encoding="utf-8") as archivo:
    json.dump(metadato, archivo, ensure_ascii=False, indent=4)

# %%
capa25 = ruta_gpkg / "tren_ligero_linea.gpkg"

metadato= {"tren_ligero_linea.gpkg": {
    "titulo": "Ubicación de líneas del Servicio de Transportes Eléctricos",
    "fuentes": [
      "Datos abiertos de la Ciudad de México: https://datos.cdmx.gob.mx/id/dataset/geolocalizacion-de-lineas-y-estaciones-paradas-del-servicio-de-transportes-electricos"
    ],
    "fecha_descarga": "2026-04-10",
    "licencias": [
      "Español - Creative Commons Attribution 4.0"
    ],
    "descripcion": "Representa la línea del Tren Ligero. Capa geográfica 'tren_ligero_linea' en formato GeoPackage con geometría tipo 3D LineString y 1 entidades.",
    "archivo": "tren_ligero_linea.gpkg",
    "formato": "GeoPackage",
    "capas": [
      {
        "nombre_capa": "tren_ligero_linea",
        "tipo_geometria": "3D LineString",
        "numero_entidades": 1,
        "crs": "PROJCS[\"WGS 84 / UTM zone 14N\",GEOGCS[\"WGS 84\",DATUM[\"WGS_1984\",SPHEROID[\"WGS 84\",6378137,298.257223563,AUTHORITY[\"EPSG\",\"7030\"]],AUTHORITY[\"EPSG\",\"6326\"]],PRIMEM[\"Greenwich\",0,AUTHORITY[\"EPSG\",\"8901\"]],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]],AUTHORITY[\"EPSG\",\"4326\"]],PROJECTION[\"Transverse_Mercator\"],PARAMETER[\"latitude_of_origin\",0],PARAMETER[\"central_meridian\",-99],PARAMETER[\"scale_factor\",0.9996],PARAMETER[\"false_easting\",500000],PARAMETER[\"false_northing\",0],UNIT[\"metre\",1,AUTHORITY[\"EPSG\",\"9001\"]],AXIS[\"Easting\",EAST],AXIS[\"Northing\",NORTH],AUTHORITY[\"EPSG\",\"32614\"]]",
        "descripcion": "Representa la línea del Tren Ligero. Capa geográfica 'tren_ligero_linea' en formato GeoPackage con geometría tipo 3D LineString y 1 entidades.",
        "variables": {
          "SISTEMA": {
            "tipo": "str",
            "descripcion": "Sistema de transporte o programa al que pertenece el elemento."
          },
          "LINEA": {
            "tipo": "str",
            "descripcion": "Identificador o nombre de la línea de transporte."
          },
          "RUTA": {
            "tipo": "str",
            "descripcion": "Nombre o identificación de la ruta."
          }
        }
      }
    ]
  }}

ruta_json = capa25.with_suffix(".json")

# Guardamos el archivo
with open(ruta_json, "w", encoding="utf-8") as archivo:
    json.dump(metadato, archivo, ensure_ascii=False, indent=4)

# %%
capa26 = ruta_gpkg / "trolebus_lineas.gpkg"

metadato= {"trolebus_lineas.gpkg": {
    "titulo": "Ubicación de líneas del Servicio de Transportes Eléctricos",
    "fuentes": [
      "Datos abiertos de la Ciudad de México: https://datos.cdmx.gob.mx/id/dataset/geolocalizacion-de-lineas-y-estaciones-paradas-del-servicio-de-transportes-electricos"
    ],
    "fecha_descarga": "2026-04-10",
    "licencias": [
      "Español - Creative Commons Attribution 4.0"
    ],
    "descripcion": "Representa líneas de Trolebús. Capa geográfica 'trolebus_lineas' en formato GeoPackage con geometría tipo 3D MultiLineString y 14 entidades.",
    "archivo": "trolebus_lineas.gpkg",
    "formato": "GeoPackage",
    "capas": [
      {
        "nombre_capa": "trolebus_lineas",
        "tipo_geometria": "3D MultiLineString",
        "numero_entidades": 14,
        "crs": "GEOGCS[\"WGS 84\",DATUM[\"WGS_1984\",SPHEROID[\"WGS 84\",6378137,298.257223563,AUTHORITY[\"EPSG\",\"7030\"]],AUTHORITY[\"EPSG\",\"6326\"]],PRIMEM[\"Greenwich\",0,AUTHORITY[\"EPSG\",\"8901\"]],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]],AXIS[\"Latitude\",NORTH],AXIS[\"Longitude\",EAST],AUTHORITY[\"EPSG\",\"4326\"]]",
        "descripcion": "Representa líneas de Trolebús. Capa geográfica 'trolebus_lineas' en formato GeoPackage con geometría tipo 3D MultiLineString y 14 entidades.",
        "variables": {
          "RUTA": {
            "tipo": "str",
            "descripcion": "Nombre o identificación de la ruta."
          },
          "SISTEMA": {
            "tipo": "str",
            "descripcion": "Sistema de transporte o programa al que pertenece el elemento."
          },
          "LINEA": {
            "tipo": "str",
            "descripcion": "Identificador o nombre de la línea de transporte."
          }
        }
      }
    ]
  }}

ruta_json = capa26.with_suffix(".json")

# Guardamos el archivo
with open(ruta_json, "w", encoding="utf-8") as archivo:
    json.dump(metadato, archivo, ensure_ascii=False, indent=4)

# %%
capa27 = ruta_gpkg / "trolebus_paradas.gpkg"

metadato= {"trolebus_paradas.gpkg": {
    "titulo": "Ubicación de estaciones/paradas del Servicio de Transportes Eléctricos",
    "fuentes": [
      "Datos abiertos de la Ciudad de México: https://datos.cdmx.gob.mx/id/dataset/geolocalizacion-de-lineas-y-estaciones-paradas-del-servicio-de-transportes-electricos"
    ],
    "fecha_descarga": "2026-04-10",
    "licencias": [
      "Español - Creative Commons Attribution 4.0"
    ],
    "descripcion": "Representa paradas de Trolebús. Capa geográfica 'trolebus_paradas' en formato GeoPackage con geometría tipo 3D Point y 805 entidades.",
    "archivo": "trolebus_paradas.gpkg",
    "formato": "GeoPackage",
    "capas": [
      {
        "nombre_capa": "trolebus_paradas",
        "tipo_geometria": "3D Point",
        "numero_entidades": 805,
        "crs": "GEOGCS[\"WGS 84\",DATUM[\"WGS_1984\",SPHEROID[\"WGS 84\",6378137,298.257223563,AUTHORITY[\"EPSG\",\"7030\"]],AUTHORITY[\"EPSG\",\"6326\"]],PRIMEM[\"Greenwich\",0,AUTHORITY[\"EPSG\",\"8901\"]],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]],AXIS[\"Latitude\",NORTH],AXIS[\"Longitude\",EAST],AUTHORITY[\"EPSG\",\"4326\"]]",
        "descripcion": "Representa paradas de Trolebús. Capa geográfica 'trolebus_paradas' en formato GeoPackage con geometría tipo 3D Point y 805 entidades.",
        "variables": {
          "SISTEMA": {
            "tipo": "str",
            "descripcion": "Sistema de transporte o programa al que pertenece el elemento."
          },
          "NOMBRE": {
            "tipo": "str",
            "descripcion": "Nombre del elemento geográfico o registro."
          },
          "TIPO": {
            "tipo": "str",
            "descripcion": "Tipo de elemento o clasificación general."
          },
          "LINEA": {
            "tipo": "str",
            "descripcion": "Identificador o nombre de la línea de transporte."
          },
          "ALCALDIAS": {
            "tipo": "str",
            "descripcion": "Alcaldía o conjunto de alcaldías asociadas al registro."
          }
        }
      }
    ]
  }}

ruta_json = capa27.with_suffix(".json")

# Guardamos el archivo
with open(ruta_json, "w", encoding="utf-8") as archivo:
    json.dump(metadato, archivo, ensure_ascii=False, indent=4)

# %%
capa28 = ruta_gpkg / "vialidades_acceso_controlado.gpkg"

metadato= {"vialidades_acceso_controlado.gpkg": {
    "titulo": "Vialidades con Acceso Controlado de la Ciudad de México",
    "fuentes": [
      "Datos abiertos de la Ciudad de México: https://datos.cdmx.gob.mx/dataset/vialidades-de-acceso-controlado"
    ],
    "fecha_descarga": "2026-04-10",
    "licencias": [
      "Español - Creative Commons Attribution 4.0"
    ],
    "descripcion": "Representa vialidades de acceso controlado. Capa geográfica 'vialidades-acceso-controlado' en formato GeoPackage con geometría tipo 3D LineString y 14 entidades.",
    "archivo": "vialidades_acceso_controlado.gpkg",
    "formato": "GeoPackage",
    "capas": [
      {
        "nombre_capa": "vialidades-acceso-controlado",
        "tipo_geometria": "3D LineString",
        "numero_entidades": 14,
        "crs": "PROJCS[\"WGS 84 / UTM zone 14N\",GEOGCS[\"WGS 84\",DATUM[\"WGS_1984\",SPHEROID[\"WGS 84\",6378137,298.257223563,AUTHORITY[\"EPSG\",\"7030\"]],AUTHORITY[\"EPSG\",\"6326\"]],PRIMEM[\"Greenwich\",0,AUTHORITY[\"EPSG\",\"8901\"]],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]],AUTHORITY[\"EPSG\",\"4326\"]],PROJECTION[\"Transverse_Mercator\"],PARAMETER[\"latitude_of_origin\",0],PARAMETER[\"central_meridian\",-99],PARAMETER[\"scale_factor\",0.9996],PARAMETER[\"false_easting\",500000],PARAMETER[\"false_northing\",0],UNIT[\"metre\",1,AUTHORITY[\"EPSG\",\"9001\"]],AXIS[\"Easting\",EAST],AXIS[\"Northing\",NORTH],AUTHORITY[\"EPSG\",\"32614\"]]",
        "descripcion": "Representa vialidades de acceso controlado. Capa geográfica 'vialidades-acceso-controlado' en formato GeoPackage con geometría tipo 3D LineString y 14 entidades.",
        "variables": {
          "Name": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: Name."
          },
          "tipo_vial": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: tipo_vial."
          },
          "entre": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: entre."
          },
          "id_vial": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: id_vial."
          }
        }
      }
    ]
  }}

ruta_json = capa28.with_suffix(".json")

# Guardamos el archivo
with open(ruta_json, "w", encoding="utf-8") as archivo:
    json.dump(metadato, archivo, ensure_ascii=False, indent=4)

# %%
capa29 = ruta_gpkg / "vialidades_primarias.gpkg"

metadato= {"vialidades_primarias.gpkg": {
    "titulo": "Vialidades Primarias",
    "fuentes": [
      "Datos abiertos de la Ciudad de México: https://datos.cdmx.gob.mx/dataset/vialidades-de-la-ciudad-de-mexico"
    ],
    "fecha_descarga": "2026-04-10",
    "licencias": [
      "Español - Creative Commons Attribution 4.0"
    ],
    "descripcion": "Representa vialidades primarias. Capa geográfica 'vialidadesPrimarias' en formato GeoPackage con geometría tipo LineString y 10567 entidades.",
    "archivo": "vialidades_primarias.gpkg",
    "formato": "GeoPackage",
    "capas": [
      {
        "nombre_capa": "vialidadesPrimarias",
        "tipo_geometria": "LineString",
        "numero_entidades": 10567,
        "crs": "PROJCS[\"WGS 84 / UTM zone 14N\",GEOGCS[\"WGS 84\",DATUM[\"WGS_1984\",SPHEROID[\"WGS 84\",6378137,298.257223563,AUTHORITY[\"EPSG\",\"7030\"]],AUTHORITY[\"EPSG\",\"6326\"]],PRIMEM[\"Greenwich\",0,AUTHORITY[\"EPSG\",\"8901\"]],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]],AUTHORITY[\"EPSG\",\"4326\"]],PROJECTION[\"Transverse_Mercator\"],PARAMETER[\"latitude_of_origin\",0],PARAMETER[\"central_meridian\",-99],PARAMETER[\"scale_factor\",0.9996],PARAMETER[\"false_easting\",500000],PARAMETER[\"false_northing\",0],UNIT[\"metre\",1,AUTHORITY[\"EPSG\",\"9001\"]],AXIS[\"Easting\",EAST],AXIS[\"Northing\",NORTH],AUTHORITY[\"EPSG\",\"32614\"]]",
        "descripcion": "Representa vialidades primarias. Capa geográfica 'vialidadesPrimarias' en formato GeoPackage con geometría tipo LineString y 10567 entidades.",
        "variables": {
          "ID_VIA": {
            "tipo": "int",
            "descripcion": "Identificador de la vialidad."
          },
          "NOMBRE": {
            "tipo": "str",
            "descripcion": "Nombre del elemento geográfico o registro."
          },
          "ID_NOM": {
            "tipo": "int",
            "descripcion": "Variable original del insumo: ID_NOM."
          },
          "NOMENCLAT": {
            "tipo": "str",
            "descripcion": "Variable original del insumo: NOMENCLAT."
          },
          "TIPO_VIA": {
            "tipo": "str",
            "descripcion": "Tipo de vialidad."
          },
          "CARRILES": {
            "tipo": "str",
            "descripcion": "Número de carriles."
          },
          "NIVEL": {
            "tipo": "int",
            "descripcion": "Nivel o jerarquía de la infraestructura."
          },
          "CIRCULA": {
            "tipo": "str",
            "descripcion": "Sentido o condición de circulación."
          },
          "ALCALDIA": {
            "tipo": "str",
            "descripcion": "Alcaldía asociada al registro."
          }
        }
      }
    ]
  }
}}

ruta_json = capa29.with_suffix(".json")

# Guardamos el archivo
with open(ruta_json, "w", encoding="utf-8") as archivo:
    json.dump(metadato, archivo, ensure_ascii=False, indent=4)
# Out:
#   Cell In[77], line 63
#     }}
#      ^
# SyntaxError: unmatched '}'
