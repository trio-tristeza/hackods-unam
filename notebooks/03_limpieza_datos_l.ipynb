# %% [markdown]
# # Carga, visualización y exportación de datos para el ODS 11
# ## Digitalización
#
# Integración de los insumos:
# - Puntos de acceso WiFi en la CDMX
# - WiFi gratuito en Postes Mi Calle
# - WiFi gratuito en Colonias Periféricas de la CDMX
# - WiFi gratuito en Utopías de la CDMX
# - WiFi gratuito en Pilares de la CDMX
# - WiFi gratuito en Unidades Habitacionales de la CDMX
# - WiFi gratuito en Postes del C5
# - WiFi gratuito en Escuelas Públicas de la CDMX
# - WiFi gratuito en Sitios Públicos de la CDMX
# - WiFi gratuito en el Transporte de la CDMX
# - WiFi gratuito en Centros de Salud

# %%
pip install pandas openpyxl geopandas

## Bibliotecas
import pandas as pd
import geopandas as gpd
import json
from shapely.geometry import shape

# %%
## Definición de rutas
ruta_csv = "../datos/crudos"
ruta_shp = "../datos/crudos/insumos/"

# %%
datos_insumos = pd.read_csv(ruta_csv+"/origendatos.csv")

# %%
datos_insumos
