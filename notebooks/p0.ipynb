# %%
import pandas as pd
import geopandas as gpd

# %%
ruta = "../datos/crudos/insumos/infraestructura_vial_ciclista/infraestructura_vial_ciclista"

# %%
datos_insumos = pd.read_csv(ruta+"/origendatos.csv")

# %%
senderos_compartidos = gpd.read_file(ruta+"/Sendero compartido.shp")
infra_ciclista_total = gpd.read_file(ruta+"/Infraestructura ciclista total.shp")

# %%
senderos_compartidos.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
infra_ciclista_total.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
infra_ciclista_total
# Out:
#      ID_TRAMO  ID_PROY                                    NOMBRE  \
# 0           1        1  Senderos Bosque de Chapultepec I Sección
# 1           2        1  Senderos Bosque de Chapultepec I Sección
# 2           3        1  Senderos Bosque de Chapultepec I Sección
# 3           4        1  Senderos Bosque de Chapultepec I Sección
# 4           5        1  Senderos Bosque de Chapultepec I Sección
# ..        ...      ...                                       ...
# 646       647      201                     Bus Bici Eje 8 Sur II
# 647       648      201                     Bus Bici Eje 8 Sur II
# 648       649      201                     Bus Bici Eje 8 Sur II
# 649       650      202                           Lago Xochimilco
# 650       651      203                            Serapio Rendón
#
#                 TIPO_IC        ALCALDIA                             VIALIDAD  \
# 0    Sendero compartido  Miguel Hidalgo                         Gran Avenida
# ...
